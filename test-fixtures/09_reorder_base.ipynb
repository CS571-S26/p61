# %% [markdown]
# # Reorder Test Notebook
#
# This notebook tests cell reordering detection.

# %%
# Cell Alpha
x = 1
print('alpha')
# Out:
# alpha

# %%
# Cell Beta
y = 2
print('beta')
# Out:
# beta

# %%
# Cell Gamma
z = 3
print('gamma')
# Out:
# gamma

# %% [markdown]
# # End
#
# This is the final cell.
